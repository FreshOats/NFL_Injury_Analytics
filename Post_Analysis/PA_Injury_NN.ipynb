# %% [markdown]
# # Post-Analysis Deep Learning of the Injury Datasets
#
# This will process the imported cleaned data from SQL
#
# ---
#
# # Dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
import tensorflow as tf

pd.set_option('mode.chained_assignment', None)
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
random_state = 42

# %%
## Connect to the Database
import sqlalchemy as db
from sqlalchemy.orm import Session
from sqlalchemy import create_engine
import psycopg2

# %% [markdown]
# # Import the Data
#
# The data has been merged and mostly cleaned in SQL and previous ETL steps. This will be extracted from the NFL_Injuries server
#
# ### Make a Connection to the SQL Server

# %%
# Make connection to the database
from config import db_password
db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/NFL_Injuries"
engine = db.create_engine(db_string)
conn = engine.connect()
metadata = db.MetaData()

del db_password

# Read in the injuries table:
table = db.Table('ml_injuries', metadata, autoload=True, autoload_with=engine)
query = db.select(table)
Results = conn.execute(query).fetchall()

# Create the new dataframe and set the keys
ml = pd.DataFrame(Results)
ml.columns = Results[0].keys()

# Close the connection and remove the unneccesary files
conn.close()

del Results, metadata, conn
ml.drop(columns=['PlayerGame', 'RosterPosition_Num'], inplace=True)

ml.head()
# Out:
#       PlayKey  time      x      y     s  PlayerGamePlay  SyntheticField  \
# 0  26624-1-13   0.0  46.31  21.97  0.09              13               1
# 1  26624-1-13   0.1  46.31  21.98  0.15              13               1
# 2  26624-1-13   0.2  46.33  21.97  0.21              13               1
# 3  26624-1-13   0.3  46.34  21.98  0.26              13               1
# 4  26624-1-13   0.4  46.33  22.01  0.29              13               1
#
#    Outdoor  Position_Num  PlayCode  DaysPlayed  InjuryType  InjuryDuration  \
# 0        1             0       0.0          64         0.0             0.0
# 1        1             0       0.0          64         0.0             0.0
# 2        1             0       0.0          64         0.0             0.0
# 3        1             0       0.0          64         0.0             0.0
# 4        1             0       0.0          64         0.0             0.0
#
#    SevereInjury  IsInjured  Twist
# 0           0.0          0  79.49
# 1           0.0          0  67.96
# 2           0.0          0  58.52
# 3           0.0          0  36.34
# 4           0.0          0  25.57

# %% [markdown]
# ### Find the End Moment of each play
#
# Since the tracking data is randomly sampled when creating the Train-Test datasets, we are separating all instances except for the final moment of each play. This will provide us with a single value per PlayKey as well as the duration of each play.

# %%
end_play = ml.sort_values(by=['PlayKey', 'time'], ascending=True)
end_play.drop_duplicates(subset=['PlayKey'], keep='last', inplace=True)
end_play.dropna(inplace=True)
end_play.set_index('PlayKey', inplace=True)
end_play.head()
# Out:
#              time      x      y     s  PlayerGamePlay  SyntheticField  \
# PlayKey
# 26624-1-13   25.5  45.20  21.74  0.23              13               1
# 26624-10-48  36.6  75.53  32.04  0.27              48               0
# 26624-11-1   25.6  26.22  25.57  1.25               1               1
# 26624-11-5   18.3  75.64  28.84  3.74               5               1
# 26624-12-10  24.3  58.66  31.11  2.37              10               1
#
#              Outdoor  Position_Num  PlayCode  DaysPlayed  InjuryType  \
# PlayKey
# 26624-1-13         1             0       0.0          64         0.0
# 26624-10-48        1             0       1.0         137         0.0
# 26624-11-1         1             0       0.0         144         0.0
# 26624-11-5         1             0       0.0         144         0.0
# 26624-12-10        1             0       0.0         151         0.0
#
#              InjuryDuration  SevereInjury  IsInjured   Twist
# PlayKey
# 26624-1-13              0.0           0.0          0   94.41
# 26624-10-48             0.0           0.0          0   24.67
# 26624-11-1              0.0           0.0          0  105.54
# 26624-11-5              0.0           0.0          0   95.28
# 26624-12-10             0.0           0.0          0   41.25

# %% [markdown]
# ---
# # Deep Learning
# ## The Tests
#
# We want to test the following conditions:
# 1. Can the model predict whether an injury occurred?
# 2. Can the model predict the type of injury?
# 3. Can the model predict whether an injury is severe?
# 4. Can the model predict the duration of the injury?
#
# Considerations for each of these tests:
# Remove PlayKey from all analyses
#
# 1. Can the model predict whether an injury occurred?
#     - y = IsInjured;
#     - Remove: InjuryType, InjuryDuration, SevereInjury, since these are all 100% correlated with injuries
#     <br>
# 2. Can the model predict the type of injury?
#     - y = InjuryType
#     - Remove: IsInjured, InjuryDuration, SevereInjury
#     - The injury duration is more likely due to the injury type, and not the other way around, so remove injury duration and severity
#     <br>
# 3. Can the model predict whether an injury is severe?
#     - y = SevereInjury
#     - Remove: InjuryDuration, IsInjured
#     <br>
# 4. Can the model predict the duration of the injury?
#     - y = InjuryDuration
#     - Remove: SevereInjury, IsInjured

# %%
# Create an output table
columns = ['Test', 'Model', 'Nodes', 'Epochs', 'Accuracy', 'Loss', 'Precision', 'Recall']
nn_table = pd.DataFrame(columns=columns)
model = 'Neural Network'

# %% [markdown]
# ## 1. Can the model predict whether an injury occurred?

# %%
# Test 1, Can the model Predict the occurrence of an Injury
X = end_play.drop(columns=['IsInjured', 'SevereInjury', 'InjuryDuration', 'InjuryType'])
y = end_play.IsInjured

# Because the True case only represents 1% of the data, the training split is stratifying on y
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=random_state)

# %%
# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit(X_train)
X_train_scaled = X_scaled.transform(X_train)
X_test_scaled = X_scaled.transform(X_test)

# %%
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 256
hidden_layer2 = 128

nn = tf.keras.models.Sequential()

# Layers
nn.add(tf.keras.layers.Dense(units=hidden_layer1,
       input_dim=number_input_features, activation='relu'))
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation='relu'))
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 256)               3072
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,097
# Trainable params: 36,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 100

# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[
           'accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=epochs)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 1s 1ms/step - loss: 0.0792 - accuracy: 0.9876 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0564 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 4/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0531 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 5/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0506 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 6/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0492 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 7/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0483 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 8/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0479 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 9/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0454 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 10/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0439 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 11/100
# 182/182 [==============================] - 0s 961us/step - loss: 0.0424 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 12/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0411 - accuracy: 0.9902 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch
-05 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000
# Epoch 95/100
# 182/182 [==============================] - 0s 928us/step - loss: 8.7055e-04 - accuracy: 0.9993 - precision: 0.9649 - recall: 0.9649
# Epoch 96/100
# 182/182 [==============================] - 0s 934us/step - loss: 0.0209 - accuracy: 0.9940 - precision: 0.7037 - recall: 0.6667
# Epoch 97/100
# 182/182 [==============================] - 0s 934us/step - loss: 0.0085 - accuracy: 0.9969 - precision: 0.8545 - recall: 0.8246
# Epoch 98/100
# 182/182 [==============================] - 0s 961us/step - loss: 0.0030 - accuracy: 0.9993 - precision: 0.9649 - recall: 0.9649
# Epoch 99/100
# 182/182 [==============================] - 0s 939us/step - loss: 0.0011 - accuracy: 0.9998 - precision: 1.0000 - recall: 0.9825
# Epoch 100/100
# 182/182 [==============================] - 0s 939us/step - loss: 4.3553e-04 - accuracy: 1.0000 - precision: 1.0000 - recall: 1.0000

# %%
# Evaluate the model using the test data
results = nn.evaluate(X_test_scaled, y_test, verbose=2)
# Out:
# 61/61 - 0s - loss: 0.1499 - accuracy: 0.9871 - precision: 0.0000e+00 - recall: 0.0000e+00 - 235ms/epoch - 4ms/step

# %%
test = "Is Injured"
loss = round(results[0], 4)
accuracy = round(results[1], 4)
precision = round(results[2], 4)
recall = round(results[3], 4)
nodes = [hidden_layer1, hidden_layer2]

row = pd.DataFrame(
    [[test, model, nodes, epochs, accuracy, loss, precision, recall]], columns=columns)
nn_table = nn_table.append(row)
nn_table
# Out:
#          Test           Model       Nodes Epochs  Accuracy    Loss  Precision  \
# 0  Is Injured  Neural Network  [256, 128]    100    0.9871  0.1499        0.0
#
#    Recall
# 0     0.0

# %% [markdown]
# ---
# ## 2. Can the model predict whether an injury is severe?

# %%
y = end_play.SevereInjury
X = end_play.drop(
    columns=['IsInjured', 'SevereInjury', 'InjuryDuration'])
# This does contain injury type - to predict whether the injury will be severe

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=random_state, stratify=y)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit(X_train)
X_train_scaled = X_scaled.transform(X_train)
X_test_scaled = X_scaled.transform(X_test)


# Establish the NN Model
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 256
hidden_layer2 = 128

nn = tf.keras.models.Sequential()

# Layers
nn.add(tf.keras.layers.Dense(units=hidden_layer1,
       input_dim=number_input_features, activation='relu'))
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation='relu'))
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 256)               3328
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 36,353
# Trainable params: 36,353
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[
           'accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=epochs)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 1s 945us/step - loss: 0.0367 - accuracy: 0.9952 - precision_1: 0.2727 - recall_1: 0.1304
# Epoch 2/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0081 - accuracy: 0.9960 - precision_1: 0.5000 - recall_1: 0.3478
# Epoch 3/100
# 182/182 [==============================] - 0s 978us/step - loss: 0.0068 - accuracy: 0.9964 - precision_1: 0.5833 - recall_1: 0.3043
# Epoch 4/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.9964 - precision_1: 0.5556 - recall_1: 0.4348
# Epoch 5/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0066 - accuracy: 0.9967 - precision_1: 0.6111 - recall_1: 0.4783
# Epoch 6/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0060 - accuracy: 0.9974 - precision_1: 0.7500 - recall_1: 0.5217
# Epoch 7/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.
- accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 82/100
# 182/182 [==============================] - 0s 1ms/step - loss: 7.4714e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 83/100
# 182/182 [==============================] - 0s 1ms/step - loss: 6.7626e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 84/100
# 182/182 [==============================] - 0s 939us/step - loss: 6.0672e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 85/100
# 182/182 [==============================] - 0s 1ms/step - loss: 5.2486e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 86/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.9497e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 87/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.4760e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 88/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.1108e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 89/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.9262e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 90/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.5892e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 91/100
# 182/182 [==============================] - 0s 994us/step - loss: 3.1063e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 92/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.9055e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 93/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.5476e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 94/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.4019e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 95/100
# 182/182 [==============================] - 0s 994us/step - loss: 2.1047e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 96/100
# 182/182 [==============================] - 0s 978us/step - loss: 1.9096e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 97/100
# 182/182 [==============================] - 0s 967us/step - loss: 1.7264e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 98/100
# 182/182 [==============================] - 0s 945us/step - loss: 1.6580e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 99/100
# 182/182 [==============================] - 0s 939us/step - loss: 1.5516e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000
# Epoch 100/100
# 182/182 [==============================] - 0s 928us/step - loss: 1.3400e-08 - accuracy: 1.0000 - precision_1: 1.0000 - recall_1: 1.0000

# %%
# Evaluate the model using the test data
results = nn.evaluate(X_test_scaled, y_test, verbose=2)

test = "Severe Injury"
loss = round(results[0], 4)
accuracy = round(results[1], 4)
precision = round(results[2], 4)
recall = round(results[3], 4)
nodes = [hidden_layer1, hidden_layer2]

row = pd.DataFrame(
    [[test, model, nodes, epochs, accuracy, loss, precision, recall]], columns=columns)
nn_table = nn_table.append(row)
nn_table
# Out:
# 61/61 - 0s - loss: 0.0746 - accuracy: 0.9948 - precision_1: 0.3333 - recall_1: 0.2500 - 208ms/epoch - 3ms/step
#             Test           Model       Nodes Epochs  Accuracy    Loss  \
# 0     Is Injured  Neural Network  [256, 128]    100    0.9871  0.1499
# 0  Severe Injury  Neural Network  [256, 128]    100    0.9948  0.0746
#
#    Precision  Recall
# 0     0.0000    0.00
# 0     0.3333    0.25

# %% [markdown]
# ---
# ## 3. Can the model predict the type of injury?

# %%
# Format this to do encoding
X_cat = end_play.copy(deep=True)
X_cat.drop(columns=['IsInjured', 'SevereInjury', 'InjuryDuration'], inplace=True)

# Change the Injury Types back the Categorical
injury = {3.0: 'Knee', 2.0: 'Ankle', 1.0: 'Foot', 0.0: 'NoInjury'}
X_cat['BodyPart'] = X_cat.InjuryType.map(injury)
X_cat.drop(columns='InjuryType', inplace=True)

X_cat.head()

# Grab all categorical variables and create a list for encoding
cat = X_cat.dtypes[X_cat.dtypes == 'object'].index.tolist()

# Create a OneHotEncoder Instance
# Create the instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHot to the columns necessary
encode_df = pd.DataFrame(enc.fit_transform(X_cat[cat]), index=X_cat.index)


# Add the original variable names to the df
encode_df.columns = enc.get_feature_names_out(cat)

# Merge the OneHot features and drop the variables
X_encoded = X_cat.merge(encode_df, left_index=True, right_index=True)
X_encoded.drop(columns=cat, inplace=True)

X_encoded.head()
# Out:
#              time      x      y     s  PlayerGamePlay  SyntheticField  \
# PlayKey
# 26624-1-13   25.5  45.20  21.74  0.23              13               1
# 26624-10-48  36.6  75.53  32.04  0.27              48               0
# 26624-11-1   25.6  26.22  25.57  1.25               1               1
# 26624-11-5   18.3  75.64  28.84  3.74               5               1
# 26624-12-10  24.3  58.66  31.11  2.37              10               1
#
#              Outdoor  Position_Num  PlayCode  DaysPlayed   Twist  \
# PlayKey
# 26624-1-13         1             0       0.0          64   94.41
# 26624-10-48        1             0       1.0         137   24.67
# 26624-11-1         1             0       0.0         144  105.54
# 26624-11-5         1             0       0.0         144   95.28
# 26624-12-10        1             0       0.0         151   41.25
#
#              BodyPart_Ankle  BodyPart_Foot  BodyPart_Knee  BodyPart_NoInjury
# PlayKey
# 26624-1-13              0.0            0.0            0.0                1.0
# 26624-10-48             0.0            0.0            0.0                1.0
# 26624-11-1              0.0            0.0            0.0                1.0
# 26624-11-5              0.0            0.0            0.0                1.0
# 26624-12-10             0.0            0.0            0.0                1.0

# %%
y = X_encoded.loc[:, 'BodyPart_Ankle':]
X_enc = X_encoded.drop(
    columns=['BodyPart_Ankle', 'BodyPart_Foot', 'BodyPart_Knee', 'BodyPart_NoInjury'])

# Because the True case only represents 1% of the data, the training split is stratifying on y
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=random_state, stratify=y)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit(X_train)
X_train_scaled = X_scaled.transform(X_train)
X_test_scaled = X_scaled.transform(X_test)


# Establish the NN Model
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 256
hidden_layer2 = 128

nn = tf.keras.models.Sequential()

# Layers
nn.add(tf.keras.layers.Dense(units=hidden_layer1,
       input_dim=number_input_features, activation='relu'))
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation='relu'))
nn.add(tf.keras.layers.Dense(units=4, activation='sigmoid'))

nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 256)               3328
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  dense_8 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 36,740
# Trainable params: 36,740
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[
           'accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=epochs)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 1s 978us/step - loss: 0.0542 - accuracy: 0.9851 - precision_2: 0.9782 - recall_2: 0.9876
# Epoch 2/100
# 182/182 [==============================] - 0s 956us/step - loss: 0.0045 - accuracy: 0.9955 - precision_2: 0.9974 - recall_2: 0.9945
# Epoch 3/100
# 182/182 [==============================] - 0s 972us/step - loss: 0.0036 - accuracy: 0.9962 - precision_2: 0.9984 - recall_2: 0.9943
# Epoch 4/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0033 - accuracy: 0.9966 - precision_2: 0.9979 - recall_2: 0.9960
# Epoch 5/100
# 182/182 [==============================] - 0s 972us/step - loss: 0.0028 - accuracy: 0.9978 - precision_2: 0.9985 - recall_2: 0.9962
# Epoch 6/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0027 - accuracy: 0.9971 - precision_2: 0.9983 - recall_2: 0.9962
- accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 78/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.8104e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 79/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.7971e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 80/100
# 182/182 [==============================] - 0s 1ms/step - loss: 4.2936e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 81/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.9192e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 82/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.4532e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 83/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.2354e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 84/100
# 182/182 [==============================] - 0s 994us/step - loss: 2.9623e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 85/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.6672e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 86/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.4843e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 87/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.4807e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 88/100
# 182/182 [==============================] - 0s 1ms/step - loss: 2.0795e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 89/100
# 182/182 [==============================] - 0s 1000us/step - loss: 1.9067e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 90/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.7634e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 91/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.5684e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 92/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.4840e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 93/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.3493e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 94/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.2609e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 95/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.2066e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 96/100
# 182/182 [==============================] - 0s 1ms/step - loss: 1.0568e-08 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 97/100
# 182/182 [==============================] - 0s 1ms/step - loss: 9.6774e-09 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 98/100
# 182/182 [==============================] - 0s 1ms/step - loss: 9.2191e-09 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 99/100
# 182/182 [==============================] - 0s 1ms/step - loss: 8.6384e-09 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000
# Epoch 100/100
# 182/182 [==============================] - 0s 1ms/step - loss: 7.7929e-09 - accuracy: 1.0000 - precision_2: 1.0000 - recall_2: 1.0000

# %%
# Evaluate the model using the test data
results = nn.evaluate(X_test_scaled, y_test, verbose=2)

test = "Body Part"
loss = round(results[0], 4)
accuracy = round(results[1], 4)
precision = round(results[2], 4)
recall = round(results[3], 4)
nodes = [hidden_layer1, hidden_layer2]

row = pd.DataFrame(
    [[test, model, nodes, epochs, accuracy, loss, precision, recall]], columns=columns)
nn_table = nn_table.append(row)
nn_table
# Out:
# 61/61 - 0s - loss: 0.0056 - accuracy: 0.9974 - precision_2: 0.9979 - recall_2: 0.9974 - 216ms/epoch - 4ms/step
#             Test           Model       Nodes Epochs  Accuracy    Loss  \
# 0     Is Injured  Neural Network  [256, 128]    100    0.9871  0.1499
# 0  Severe Injury  Neural Network  [256, 128]    100    0.9948  0.0746
# 0      Body Part  Neural Network  [256, 128]    100    0.9974  0.0056
#
#    Precision  Recall
# 0     0.0000  0.0000
# 0     0.3333  0.2500
# 0     0.9979  0.9974

# %% [markdown]
# ---
# ## 4. Can the model predict the duration of the injury?

# %%
# Format this to do encoding
X_cat = end_play.copy(deep=True)
X_cat.drop(columns=['IsInjured', 'SevereInjury', 'InjuryType'], inplace=True)

# Change the Injury Types back the Categorical
duration = {0.0: 'NoInjury', 1.0: 'Under_1_Week', 7.0: 'Under_4_Weeks', 28.0: 'Under_6_Weeks', 42.0: 'Over_6_Weeks'}
X_cat['Durations'] = X_cat.InjuryDuration.map(duration)
X_cat.drop(columns='InjuryDuration', inplace=True)

# Grab all categorical variables and create a list for encoding
cat = X_cat.dtypes[X_cat.dtypes == 'object'].index.tolist()

# Create a OneHotEncoder Instance
# Create the instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHot to the columns necessary
encode_df = pd.DataFrame(enc.fit_transform(X_cat[cat]), index=X_cat.index)

# Add the original variable names to the df
encode_df.columns = enc.get_feature_names_out(cat)

# Merge the OneHot features and drop the variables
X_encoded = X_cat.merge(encode_df, left_index=True, right_index=True)
X_encoded.drop(columns=cat, inplace=True)

X_encoded.head()
# Out:
#              time      x      y     s  PlayerGamePlay  SyntheticField  \
# PlayKey
# 26624-1-13   25.5  45.20  21.74  0.23              13               1
# 26624-10-48  36.6  75.53  32.04  0.27              48               0
# 26624-11-1   25.6  26.22  25.57  1.25               1               1
# 26624-11-5   18.3  75.64  28.84  3.74               5               1
# 26624-12-10  24.3  58.66  31.11  2.37              10               1
#
#              Outdoor  Position_Num  PlayCode  DaysPlayed   Twist  \
# PlayKey
# 26624-1-13         1             0       0.0          64   94.41
# 26624-10-48        1             0       1.0         137   24.67
# 26624-11-1         1             0       0.0         144  105.54
# 26624-11-5         1             0       0.0         144   95.28
# 26624-12-10        1             0       0.0         151   41.25
#
#              Durations_NoInjury  Durations_Over_6_Weeks  \
# PlayKey
# 26624-1-13                  1.0                     0.0
# 26624-10-48                 1.0                     0.0
# 26624-11-1                  1.0                     0.0
# 26624-11-5                  1.0                     0.0
# 26624-12-10                 1.0                     0.0
#
#              Durations_Under_1_Week  Durations_Under_4_Weeks  \
# PlayKey
# 26624-1-13                      0.0                      0.0
# 26624-10-48                     0.0                      0.0
# 26624-11-1                      0.0                      0.0
# 26624-11-5                      0.0                      0.0
# 26624-12-10                     0.0                      0.0
#
#              Durations_Under_6_Weeks
# PlayKey
# 26624-1-13                       0.0
# 26624-10-48                      0.0
# 26624-11-1                       0.0
# 26624-11-5                       0.0
# 26624-12-10                      0.0

# %%
y = X_encoded.loc[:, 'Durations_NoInjury':]
X_enc = X_encoded.drop(
    columns=['Durations_NoInjury', 'Durations_Over_6_Weeks', 'Durations_Under_1_Week', 'Durations_Under_4_Weeks', 'Durations_Under_6_Weeks'])

# Because the True case only represents 1% of the data, the training split is stratifying on y
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=random_state, stratify=y)

# Scale the data
scaler = StandardScaler()
X_scaled = scaler.fit(X_train)
X_train_scaled = X_scaled.transform(X_train)
X_test_scaled = X_scaled.transform(X_test)


# Establish the NN Model
number_input_features = len(X_train_scaled[0])
hidden_layer1 = 256
hidden_layer2 = 128

nn = tf.keras.models.Sequential()

# Layers
nn.add(tf.keras.layers.Dense(units=hidden_layer1,
       input_dim=number_input_features, activation='relu'))
nn.add(tf.keras.layers.Dense(units=hidden_layer2, activation='relu'))
nn.add(tf.keras.layers.Dense(units=5, activation='sigmoid'))

nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 256)               3328
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  dense_11 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 36,869
# Trainable params: 36,869
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=[
           'accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall()])

# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=epochs)
# Out:
# Epoch 1/100
# 182/182 [==============================] - 1s 945us/step - loss: 0.0606 - accuracy: 0.9775 - precision_3: 0.9648 - recall_3: 0.9804
# Epoch 2/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0049 - accuracy: 0.9930 - precision_3: 0.9991 - recall_3: 0.9905
# Epoch 3/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0044 - accuracy: 0.9933 - precision_3: 0.9991 - recall_3: 0.9916
# Epoch 4/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0041 - accuracy: 0.9947 - precision_3: 0.9997 - recall_3: 0.9905
# Epoch 5/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0040 - accuracy: 0.9948 - precision_3: 0.9979 - recall_3: 0.9921
# Epoch 6/100
# 182/182 [==============================] - 0s 994us/step - loss: 0.0040 - accuracy: 0.9933 - precision_3: 0.9986 - recall_3: 0.9918
# Epoch 7/100
# 182/182 [==============================] - 0s 1ms/step - loss: 0.0039 - accuracy: 0.9945 - precision_3: 0.9984 - recall_3: 0.9921
# Epoch 8/100
# 182/182 [==============================] - 0s 972us/step - loss: 0.0036 - accuracy: 0.9954 - precision_3: 0.9986 - recall_3: 0.9930
# Epoch 9/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0035 - accuracy: 0.9952 - precision_3: 0.9983 - recall_3: 0.9935
# Epoch 10/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0033 - accuracy: 0.9959 - precision_3: 0.9988 - recall_3: 0.9936
# Epoch 11/100
# 182/182 [==============================] - 0s 967us/step - loss: 0.0032 - accuracy: 0.9960 - precision_3: 0.9984 - recall_3: 0.9945
# Epoch 12/100
# 182/182 [==============================] - 0s 961us/step - loss: 0.0030 - accuracy: 0.9969 - precision_3: 0.9986 - recall_3: 0.9945
# Epoch 13/100
# 182/182 [==============================] - 0s 950us/step - loss: 0.0028 - accuracy: 0.9978 - precision_3: 0.9986 - recall_3: 0.9950
# Epoch 14/100
# 182/182 [==============================] - 0s 939us/step - loss: 0.0026 - accuracy: 0.9978 - precision_3: 0.9983 - recall_3: 0.9960
# Epoch 15/100
# 182/182 [==============================] - 0s 978us/step - loss: 0.0024 - accuracy: 0.9979 - precision_3: 0.9979 - recall_3: 0.9966
# Epoch 16/100
# 182/182 [==============================] - 0s 939us/step - loss: 0.0021 - accuracy: 0.9979 - precision_3: 0.9983 - recall_3: 0.9967
# Epoch 17/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0020 - accuracy: 0.9986 - precision_3: 0.9988 - recall_3: 0.9973
# Epoch 18/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0016 - accuracy: 0.9986 - precision_3: 0.9991 - recall_3: 0.9981
# Epoch 19/100
# 182/182 [==============================] - 0s 934us/step - loss: 0.0015 - accuracy: 0.9986 - precision_3: 0.9991 - recall_3: 0.9981
# Epoch 20/100
# 182/182 [==============================] - 0s 945us/step - loss: 0.0012 - accuracy: 0.9988 - precision_3: 0.9995 - recall_3: 0.9986
# Epoch 21/100
- accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 94/100
# 182/182 [==============================] - 0s 1ms/step - loss: 5.1026e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 95/100
# 182/182 [==============================] - 0s 978us/step - loss: 4.6317e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 96/100
# 182/182 [==============================] - 0s 989us/step - loss: 4.1855e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 97/100
# 182/182 [==============================] - 0s 983us/step - loss: 4.2781e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 98/100
# 182/182 [==============================] - 0s 989us/step - loss: 3.6268e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 99/100
# 182/182 [==============================] - 0s 989us/step - loss: 3.2666e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000
# Epoch 100/100
# 182/182 [==============================] - 0s 1ms/step - loss: 3.0830e-08 - accuracy: 1.0000 - precision_3: 1.0000 - recall_3: 1.0000

# %%
# Evaluate the model using the test data
results = nn.evaluate(X_test_scaled, y_test, verbose=2)

# Add results to table
test = "Injury Duration"
loss = round(results[0], 4)
accuracy = round(results[1], 4)
precision = round(results[2], 4)
recall = round(results[3], 4)
nodes = [hidden_layer1, hidden_layer2]

row = pd.DataFrame(
    [[test, model, nodes, epochs, accuracy, loss, precision, recall]], columns=columns)
nn_table = nn_table.append(row)
nn_table
# Out:
# 61/61 - 0s - loss: 0.0376 - accuracy: 0.9928 - precision_3: 0.9943 - recall_3: 0.9928 - 210ms/epoch - 3ms/step
#               Test           Model       Nodes Epochs  Accuracy    Loss  \
# 0       Is Injured  Neural Network  [256, 128]    100    0.9871  0.1499
# 0    Severe Injury  Neural Network  [256, 128]    100    0.9948  0.0746
# 0        Body Part  Neural Network  [256, 128]    100    0.9974  0.0056
# 0  Injury Duration  Neural Network  [256, 128]    100    0.9928  0.0376
#
#    Precision  Recall
# 0     0.0000  0.0000
# 0     0.3333  0.2500
# 0     0.9979  0.9974
# 0     0.9943  0.9928

# %%
# Export the results table to the repo

# nn_table.to_csv("NeuralNetwork_Results.csv")

# %%
# # Make connection to the database
# from config import db_password
# db_string = f"postgresql://postgres:{db_password}@127.0.0.1:5433/NFL_Injuries"
# engine = db.create_engine(db_string)
# del db_string, db_password

# Write table to database
# nn_table.to_sql(name='Neural_Network_Outputs', con=engine, index=False)

# %% [markdown]
# ---
#
# # Summary
#
# For an injury analysis such as this, it is more important that our model achieve a high precision, rather than a high accuracy or recall. The accuracy only tells us how many true positives have been classified, however, the data are extremely imbalanced, which is a known problem with the accuracy measure. While it looks great to have 4 models acheive nearly 99% accuracy, this isn't indicative of a good predictive model for our purpose. Even if all of the injuries were classified as Non-Injuries, the model would be predicting above 95% if the Non-Injury is evaluated as the True Positive Measure, and nearly 0% if we consider the Injuries as the true positive. Meanwhile, the Precision gives us the count of the True Positives with respect to the True Positives and False Negatives.
#
# In the case that the True Positive is the injury we are evaluating, the False Negative would represent a player who is injured, but was classified as Not Injured. Our precision varied, with a very low precision in predicting whether an injury occurred without considering any details about injury type. An explanation for this is that plays meeting the critera of a high-risk play, potentially prone to injury did not result in an injury at that time, but the activity could not be differentiated from similar circumnstances that did lead to injury.
#
# From a medical-analytical perspective, this gives us insights as to what parameters can lead to injurious plays based on the utilized features of the players along with the other features analyzed. This improves upon our previous model that had erroneously applied the tracking data.
#
#
# ## Future Analysis
#
# This model uses the end-time from each play, since the Train-Test Split randomly splits the data. In this case, we were able to split by index, separating the positive and negative cases fairly. However, I would like to further split the testing-training set indices prior to the tracking merge so that we can utilize the full path of the player leading to the injury for further insight.
